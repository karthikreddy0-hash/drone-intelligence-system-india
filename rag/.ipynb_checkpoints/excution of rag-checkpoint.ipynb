# %%
from docx import Document
import os
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
import os

print(os.listdir("data/raw"))
# Out:
# ['business _opportunities _india.docx', 'drone _use _cases _and_ success_ stories.docx', 'drone_ Regulations _in_ India.docx', 'technical _comparison _drone_specifications.docx']

# %%
def load_docx(folder_path):
    documents = []
    
    for file in os.listdir(folder_path):
        if file.endswith(".docx"):
            doc = Document(os.path.join(folder_path, file))
            text = "\n".join([para.text for para in doc.paragraphs])
            documents.append(text)
    
    return documents

docs = load_docx("data/raw")

print("Documents loaded:", len(docs))
# Out:
# Documents loaded: 4

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.create_documents(docs)

print("Total chunks created:", len(chunks))
# Out:
# Total chunks created: 13

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
vectorstore = FAISS.from_documents(chunks, embeddings)

print("Vector database created successfully!")
# Out:
# Vector database created successfully!

# %%
query = "Explain drone regulations in India"

results = vectorstore.similarity_search(query, k=1)

for doc in results:
    
    print(doc.page_content)
# Out:
# Drone Regulations in India
# Introduction
# Drone operations in India are governed by the Drone Rules 2021 issued by the Ministry of Civil Aviation and implemented by the Directorate General of Civil Aviation (DGCA). These rules aim to balance innovation, economic growth, and national security. The regulatory framework simplifies drone approvals while ensuring safety, accountability, and airspace control.
# Classification of Drones
# Drones are categorized based on Maximum Take-Off Weight (MTOW):

# %%
import requests
import json

API_KEY = "AIzaSyAoa4QAPKirnZNY7tNB_aSER3N3rbZ9MnU"

def generate_with_gemini(prompt):
    
    url = f"https://generativelanguage.googleapis.com/v1/models/gemini-2.5-flash:generateContent?key={API_KEY}"
    
    headers = {
        "Content-Type": "application/json"
    }
    
    data = {
        "contents": [
            {
                "parts": [
                    {"text": prompt}
                ]
            }
        ]
    }
    
    response = requests.post(url, headers=headers, data=json.dumps(data))
    
    result = response.json()
    
    return result

# %%
def ask_rag(query):
    
    # Step 1: Retrieve from FAISS
    results = vectorstore.similarity_search(query, k=3)
    
    context = ""
    for doc in results:
        context += doc.page_content + "\n\n"
    
    # Step 2: Create prompt
    prompt = f"""
    You are an AI assistant for India's Drone Intelligence System.
    
    Use the context below to answer clearly and professionally.
    
    Context:
    {context}
    
    Question:
    {query}
    """
    
    # Step 3: Send to Gemini (Generation Component)
    final_answer = generate_with_gemini(prompt)
    
    return final_answer

# %%
answer = ask_rag("Explain drone regulations in india")
print(answer)
# Out:
# {'candidates': [{'content': {'parts': [{'text': 'Drone operations in India are governed by the **Drone Rules 2021**, issued by the Ministry of Civil Aviation and implemented by the **Directorate General of Civil Aviation (DGCA)**.\n\nThe core objectives of these regulations are to:\n*   Balance innovation and economic growth with national security.\n*   Simplify drone approvals.\n*   Ensure safety, accountability, and proper airspace control.\n\nKey aspects of the regulations include:\n*   **Classification of Drones:** Drones are categorized based on their **Maximum Take-Off Weight (MTOW)**.\n*   **Penalties for Violations:** Failure to comply with the rules can lead to various penalties, ranging from a warning or minor fine to a fine of up to INR 100,000, license suspension, legal action, or even severe legal action.\n\nThe Indian government is continuously reforming these regulations to further simplify compliance processes, with the aim of establishing India as a global drone hub by encouraging domestic manufacturing, research, and startup participation.'}], 'role': 'model'}, 'finishReason': 'STOP', 'index': 0}], 'usageMetadata': {'promptTokenCount': 318, 'candidatesTokenCount': 212, 'totalTokenCount': 742, 'promptTokensDetails': [{'modality': 'TEXT', 'tokenCount': 318}], 'thoughtsTokenCount': 212}, 'modelVersion': 'gemini-2.5-flash', 'responseId': 'eNajaaGTH62ljuMP8vOv-QE'}
