# %%
# !python preprocess_data.py
# Out:
# Business data processed successfully!
# Preprocessing completed successfully!

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Karthik Reddy\\drone_intelligence\\scripts'

# %%
import os
os.listdir("data/synthetic")
# Out:
# ['business_scenarios.csv', 'cost_benefit_data.csv', 'drone_flight_data.csv']

# %%
import os 
os.listdir("data/processed")
# Out:
# ['processed_business_data.csv',
#  'processed_cost_data.csv',
#  'processed_flight_data.csv']

# %%
# !python run_pipeline.py
# Out:
# Business data processed successfully!
# Preprocessing completed successfully!
# Running Data Pipeline...
# Data Pipeline Completed Successfully!
